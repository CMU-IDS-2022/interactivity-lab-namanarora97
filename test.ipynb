# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_csv('pulse39.csv')

# %%
df
# Out:
#       sexual_orientation  hispanic            race         education  \
# 0               Straight     False           White      Some college
# 1                    NaN     False           White      Some college
# 2               Bisexual     False  Other/multiple      Some college
# 3               Straight     False           White   Graduate degree
# 4               Straight     False           Black      Some college
# ...                  ...       ...             ...               ...
# 57059           Straight     False           White      Some college
# 57060           Straight      True           White   Graduate degree
# 57061           Straight     False           White  Bachelors degree
# 57062           Straight     False           White   Graduate degree
# 57063           Straight     False           White   Graduate degree
#
#       marital_status  num_children_hhld  gender  age age_group  \
# 0            Married                  0    Male   67       65+
# ...

# %%
list(df.gender.unique())
# Out:
# ['Male', 'Female', 'None of these', 'Transgender']

# %%
list(df.race.unique())
# Out:
# ['White', 'Other/multiple', 'Black', 'Asian']

# %%
df.education.value_counts()
# Out:
# Bachelors degree                      16287
# Graduate degree                       15031
# Some college                          12234
# High school graduate or equivalent     6486
# Associates degree                      5914
# Some high school                        750
# Less than high school                   362
# Name: education, dtype: int64

# %%
df.loc[0,'age']
# Out:
# 67

# %%
df.columns
# Out:
# Index(['sexual_orientation', 'hispanic', 'race', 'education', 'marital_status',
#        'num_children_hhld', 'gender', 'age', 'age_group', 'received_vaccine',
#        'vaccine_intention',
#        'why_no_vaccine_Concerned about possible side effects',
#        'why_no_vaccine_Don't know if it will protect me',
#        'why_no_vaccine_Don't believe I need it',
#        'why_no_vaccine_Doctor has not recommended',
#        'why_no_vaccine_Wait and see if it is safe',
#        'why_no_vaccine_Concerned about cost',
#        'why_no_vaccine_Don't trust COVID-19 vaccines',
#        'why_no_vaccine_Don't trust the government',
#        'why_no_vaccine_Don't think COVID-19 is a big threat',
#        'why_no_vaccine_Hard to get a COVID-19 vaccine',
#        'why_no_vaccine_Believe 1 dose is enough',
#        'why_no_vaccine_Experienced side effects from one dose',
#        'why_no_vaccine_Other reason', 'had_covid', 'income',
# ...

# %%
df.received_vaccine.value_counts()
# Out:
# True     50115
# False     6949
# Name: received_vaccine, dtype: int64
